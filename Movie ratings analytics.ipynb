# %%
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Keshav Chaudhary\\Desktop\\python program'

# %%
movies = pd.read_csv("MovieRatings.csv")

# %%
len(movies)
# Out:
# 559

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.columns = ['Film','Genre','CriticRating','AudienceRating','BudgetMilloions','Year']

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMilloions  Year
# 0                8  2009
# 1              105  2008
# 2               20  2009
# 3               18  2010
# 4               20  2009

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film               559 non-null object
# Genre              559 non-null object
# CriticRating       559 non-null int64
# AudienceRating     559 non-null int64
# BudgetMilloions    559 non-null int64
# Year               559 non-null int64
# dtypes: int64(4), object(2)
# memory usage: 21.9+ KB

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMilloions         Year
# count    559.000000      559.000000       559.000000   559.000000
# mean      47.309481       58.744186        50.236136  2009.152057
# std       26.413091       16.826887        48.731817     1.362632
# min        0.000000        0.000000         0.000000  2007.000000
# 25%       25.000000       47.000000        20.000000  2008.000000
# 50%       46.000000       58.000000        35.000000  2009.000000
# 75%       70.000000       72.000000        65.000000  2010.000000
# max       97.000000       96.000000       300.000000  2011.000000

# %%
movies['Film']
# Out:
# 0                   (500) Days of Summer
# 1                             10,000 B.C.
# 2                              12 Rounds
# 3                               127 Hours
# 4                               17 Again
# 5                                    2012
# 6                              27 Dresses
# 7                        30 Days of Night
# 8                      30 Minutes or Less
# 9                                   50/50
# 10                             88 Minutes
# 11                     A Dangerous Method
# 12              A Nightmare on Elm Street
# 13                         A Serious Man
# 14      A Very Harold and Kumar Christmas
# 15                              Abduction
# 16                    Across the Universe
# 17                         Adventureland
# 18                           Albert Nobbs
# 19                    Alice in Wonderland
# 20          Alien vs. Predator -- Requiem
# 21                   Aliens in the Attic
# ...

# %%
movies.Film = movies.Film.astype('category')

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMilloions  Year
# 0                8  2009
# 1              105  2008
# 2               20  2009
# 3               18  2010
# 4               20  2009

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film               559 non-null category
# Genre              559 non-null object
# CriticRating       559 non-null int64
# AudienceRating     559 non-null int64
# BudgetMilloions    559 non-null int64
# Year               559 non-null int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 35.0+ KB

# %%
movies.Genre = movies.Genre.astype('category')
movies.Year = movies.Year.astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film               559 non-null category
# Genre              559 non-null category
# CriticRating       559 non-null int64
# AudienceRating     559 non-null int64
# BudgetMilloions    559 non-null int64
# Year               559 non-null category
# dtypes: category(3), int64(3)
# memory usage: 29.9 KB

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMilloions
# count    559.000000      559.000000       559.000000
# mean      47.309481       58.744186        50.236136
# std       26.413091       16.826887        48.731817
# min        0.000000        0.000000         0.000000
# 25%       25.000000       47.000000        20.000000
# 50%       46.000000       58.000000        35.000000
# 75%       70.000000       72.000000        65.000000
# max       97.000000       96.000000       300.000000

# %%
movies.Genre = movies.Genre.astype('category'
movies.Year = movies.Year.astype('category')

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
#jointplots

# %%
j = sns.jointplot(data=movies, x='CriticRating',y='AudienceRating')

# %%
j = sns.jointplot(data=movies, x='CriticRating',y='AudienceRating',kind='hex' )

# %%
##<<< charts

# %% [markdown]
# ---

# %%
#Histograms

# %%
#already know this method:
m1 = sns.distplot(movies.AudienceRating ,bins=15)

# %%
m2 = sns.distplot(movies.CriticRating ,bins=15)

# %%
sns.set_style("white")
n1 = plt.hist(movies.AudienceRating,bins=15)

# %%
#Stacked histograms

# %%
plt.hist(movies.BudgetMilloions)
plt.show()

# %%
plt.hist(movies.BudgetMilloions)
plt.show()

# %%
movies[movies.Genre == 'Drama'].BudgetMilloions
# Out:
# 10      30
# 11      20
# 13       7
# 18       8
# 23      20
# 26       8
# 27      30
# 47      13
# 53      26
# 55       2
# 56      55
# 62      55
# 74      15
# 84      25
# 96      37
# 99      25
# 112     60
# 116     21
# 117      5
# 119     31
# 120     40
# 128      1
# 131     24
# 132     21
# 151     33
# 158     16
# 171      7
# 195     15
# 199     35
# 213     10
#       ...
# 437     13
# 442     20
# 444      2
# 445     20
# 446     40
# 450     65
# 457     40
# 466     45
# 467     11
# 470     60
# 480     39
# 482     32
# 483     68
# 484     50
# 487      0
# 488      4
# 489    150
# 490     16
# 492     25
# 508     20
# 509     10
# 511      2
# 516     25
# 523     26
# 527     70
# 529     66
# 532     38
# 534     21
# 541     15
# 545      2
# Name: BudgetMilloions, Length: 101, dtype: int64

# %%
plt.hist(movies[movies.Genre == 'Action'].BudgetMilloions,bins=15)
plt.hist(movies[movies.Genre == 'Comedy'].BudgetMilloions,bins=10)
plt.hist(movies[movies.Genre == 'Adventure'].BudgetMilloions,bins=20)
plt.show()

# %%
plt.hist(movies[movies.Genre == 'Comedy'].BudgetMilloions,bins=15)
plt.show()

# %%
plt.hist([movies[movies.Genre == 'Action'].BudgetMilloions , movies[movies.Genre == 'Comedy'].BudgetMilloions] ,bins=15, stacked=True)
plt.show()

# %%
plt.hist([movies[movies.Genre == 'Action'].BudgetMilloions , movies[movies.Genre == 'Comedy'].BudgetMilloions] ,bins=15)
plt.show()

# %%
plt.hist([movies[movies.Genre == 'Action'].BudgetMilloions , movies[movies.Genre == 'Comedy'].BudgetMilloions , movies[movies.Genre == 'Adventure'].BudgetMilloions],bins=15)
plt.show()

# %%
for gen in movies.Genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
movies.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
list1 = list()
for gen in movies.Genre.cat.categories:
    list1.append(movies[movies.Genre == gen].BudgetMilloions)
print(list1)
# Out:
# [2       20
# 5      200
# 15      35
# 29      20
# 30      20
# 33     237
# 36      45
# 39      45
# 40      70
# 45     150
# 49      68
# 52      17
# 58     140
# 60      85
# 63      40
# 66     125
# 67      25
# 69      40
# 70      90
# 73      30
# 76     163
# 77      13
# 81      25
# 83      20
# 86      45
# 94      30
# 98      33
# 101     75
# 102     30
# 106     45
#       ...
# 433    138
# 435     50
# 439     40
# 441     80
# 443    150
# 448     25
# 451     40
# 454    145
# 458    100
# 472    150
# 473      6
# 474      0
# 477    100
# 479     75
# 493    150
# 495     35
# 499    150
# 500    195
# 501    210
# 502     30
# 504    170
# 512     35
# 514     95
# 528     75
# 530     25
# 531    130
# 542     35
# 546    150
# 547    160
# 557     24
# Name: BudgetMilloions, Length: 154, dtype: int64, 1      105
# 3       18
# 19     200
# 21      45
# 24      40
# 32      78
# 46      20
# 65      38
# 68     140
# 130     73
# 165     12
# 166    125
# ...

# %%
list1 = list()
mylabels = list()
for gen in movies.Genre.cat.categories:
    list1.append(movies[movies.Genre == gen].BudgetMilloions)
    mylabels.append(gen)
h = plt.hist(list1, bins=15, stacked=True, label=mylabels)
plt.legend()
plt.show()

# %%
#KDE plot

# %%
vis1 = sns.lmplot(data=movies, x='CriticRating',y='AudienceRating' , fit_reg=False ,hue='Genre' , size=7 ,aspect=1)

# %%
k1 = sns.kdeplot(movies.CriticRating  ,movies.AudienceRating)

# %%
k1 = sns.kdeplot(movies.CriticRating  ,movies.AudienceRating ,shade=True)

# %%
k1 = sns.kdeplot(movies.CriticRating  ,movies.AudienceRating ,shade=True ,shade_lowest=False)

# %%
k1 = sns.kdeplot(movies.CriticRating  ,movies.AudienceRating ,shade=True ,shade_lowest=False , cmap='Reds')

# %%
k1 = sns.kdeplot(movies.CriticRating  ,movies.AudienceRating ,shade=True ,shade_lowest=False , cmap='Reds')
#TIP
k1b = k1 = sns.kdeplot(movies.CriticRating  ,movies.AudienceRating , cmap='Reds')

# %%
#working with subplots:

# %%
k1 = sns.kdeplot(movies.BudgetMilloions  ,movies.AudienceRating )

# %%
sns.set_style("dark")
k1 = sns.kdeplot(movies.BudgetMilloions  ,movies.AudienceRating )

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
f, ax = plt.subplots(1,2 , figsize=(12,6))

# %%
f, axes = plt.subplots(1,2 , figsize=(12,6))
k1 = sns.kdeplot(movies.BudgetMilloions  ,movies.AudienceRating )
k2 = sns.kdeplot(movies.BudgetMilloions , movies.CriticRating)

# %%
f, axes = plt.subplots(1,2 , figsize=(12,6))
k1 = sns.kdeplot(movies.BudgetMilloions  ,movies.AudienceRating ,ax=axes[0])
k2 = sns.kdeplot(movies.BudgetMilloions , movies.CriticRating ,ax=axes[1])

# %%
f, axes = plt.subplots(2,2 , figsize=(12,6))
k1 = sns.kdeplot(movies.BudgetMilloions  ,movies.AudienceRating ,ax=axes[0,1])
k2 = sns.kdeplot(movies.BudgetMilloions , movies.CriticRating ,ax=axes[1,1])

# %%
f, axes = plt.subplots(1,2 , figsize=(12,6) , sharex=True , sharey=True)
k1 = sns.kdeplot(movies.BudgetMilloions  ,movies.AudienceRating ,ax=axes[0])
k2 = sns.kdeplot(movies.BudgetMilloions , movies.CriticRating ,ax=axes[1])
k1.set(xlim=(-20,160))
# Out:
# [(-20, 160)]

# %%
#violineplots

# %%
z = sns.violinplot(data=movies ,x='Genre' , y='CriticRating')

# %%
w = sns.boxplot(data=movies ,x='Genre' , y='CriticRating')

# %%
w = sns.boxplot(data=movies[movies.Genre=='Drama'] ,x='Year' , y='CriticRating')

# %%
#creating a facet grid

# %%
g = sns.FacetGrid(movies, row='Genre', col='Year' , hue='Genre')

# %%
plt.scatter(movies.CriticRating,movies.AudienceRating)

# %%
g = sns.FacetGrid(movies, row='Genre', col='Year' , hue='Genre')
g = g.map(plt.scatter , 'CriticRating' , 'AudienceRating')

# %%
#can populte with any type of chart ..example-histogram
g = sns.FacetGrid(movies, row='Genre', col='Year' , hue='Genre')
g = g.map(plt.hist , 'BudgetMilloions')

# %%
#back to the scatter plots:
g = sns.FacetGrid(movies, row='Genre', col='Year' , hue='Genre')
kws = dict(s=50 , linewidth=0.5, edgecolor='Black')
g = g.map(plt.scatter , 'CriticRating' , 'AudienceRating', **kws)

# %%
#controlling axes and adding Diagonals
g = sns.FacetGrid(movies, row='Genre', col='Year' , hue='Genre')
kws = dict(s=50 , linewidth=0.5, edgecolor='Black')
g = g.map(plt.scatter , 'CriticRating' , 'AudienceRating', **kws)
g.set(xlim=(0,100) , ylim=(0,100))

# %%
g = sns.FacetGrid(movies, row='Genre', col='Year' , hue='Genre')
kws = dict(s=50 , linewidth=0.5, edgecolor='Black')
g = g.map(plt.scatter , 'CriticRating' , 'AudienceRating', **kws)
g.set(xlim=(0,100) , ylim=(0,100))
for ax in g.axes.flat:
    ax.plot((0,100) ,(0,100) , c="gray" , ls="--")

# %%
g = sns.FacetGrid(movies, row='Genre', col='Year' , hue='Genre')
kws = dict(s=50 , linewidth=0.5, edgecolor='Black')
g = g.map(plt.scatter , 'CriticRating' , 'AudienceRating', **kws)
g.set(xlim=(0,100) , ylim=(0,100))
for ax in g.axes.flat:
    ax.plot((0,100) ,(0,100) , c="gray" , ls="--")
g.add_legend()

# %%
#Building Dashboards

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
sns.set_style("darkgrid")
f, axes = plt.subplots(2,2, figsize=(15,15))
k1 = sns.kdeplot(movies.BudgetMilloions  ,movies.AudienceRating ,ax=axes[0,0])
k2 = sns.kdeplot(movies.BudgetMilloions , movies.CriticRating ,ax=axes[0,1])
z = sns.violinplot(data=movies[movies.Genre=='Drama'] ,x='Year' , y='CriticRating' , ax=axes[1,0])
k4 = sns.kdeplot(movies.CriticRating  ,movies.AudienceRating ,shade=True ,shade_lowest=False , cmap='Reds', ax=axes[1,1])
#TIP
k4b = k1 = sns.kdeplot(movies.CriticRating  ,movies.AudienceRating , cmap='Reds',ax=axes[1,1])
k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))
# Out:
# [(-20, 160)]

# %%
sns.set_style("darkgrid")
f, axes = plt.subplots(2,2, figsize=(15,15))
k1 = sns.kdeplot(movies.BudgetMilloions  ,movies.AudienceRating ,ax=axes[0,0])
k2 = sns.kdeplot(movies.BudgetMilloions , movies.CriticRating ,ax=axes[0,1])
z = sns.violinplot(data=movies[movies.Genre=='Drama'] ,x='Year' , y='CriticRating' , ax=axes[1,0])
axes[1,1].hist(movies.AudienceRating,bins=15)
k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))
# Out:
# [(-20, 160)]

# %%
#styling Dashboards

# %%
sns.set_style("darkgrid")
f, axes = plt.subplots(2,2, figsize=(15,15))
#plot[0,0]
k1 = sns.kdeplot(movies.BudgetMilloions  ,movies.AudienceRating ,shade=True ,shade_lowest=True , cmap='inferno',ax=axes[0,0])
k1b = sns.kdeplot(movies.BudgetMilloions  ,movies.AudienceRating , cmap='cool',ax=axes[0,0])
#plot[0,1]
k2 = sns.kdeplot(movies.BudgetMilloions , movies.CriticRating ,shade=True ,shade_lowest=True , cmap='inferno' , ax=axes[0,1])
k2b = sns.kdeplot(movies.BudgetMilloions , movies.CriticRating, cmap='cool' , ax=axes[0,1])
#plot[1,0]
z = sns.violinplot(data=movies[movies.Genre=='Drama'] ,x='Year' , y='CriticRating' , ax=axes[1,0])
#plot[1,1]
axes[1,1].hist(movies.AudienceRating,bins=15)
k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))
# Out:
# [(-20, 160)]

# %%
sns.set_style("dark" , {"axes.facecolor": "black"})
f, axes = plt.subplots(2,2, figsize=(15,15))
#plot[0,0]
k1 = sns.kdeplot(movies.BudgetMilloions  ,movies.AudienceRating ,shade=True ,shade_lowest=True , cmap='inferno',ax=axes[0,0])
k1b = sns.kdeplot(movies.BudgetMilloions  ,movies.AudienceRating , cmap='cool',ax=axes[0,0])
#plot[0,1]
k2 = sns.kdeplot(movies.BudgetMilloions , movies.CriticRating ,shade=True ,shade_lowest=True , cmap='inferno' , ax=axes[0,1])
k2b = sns.kdeplot(movies.BudgetMilloions , movies.CriticRating, cmap='cool' , ax=axes[0,1])
#plot[1,0]
z = sns.violinplot(data=movies[movies.Genre=='Drama'] ,x='Year' , y='CriticRating' , ax=axes[1,0])
#plot[1,1]
axes[1,1].hist(movies.AudienceRating,bins=15)
k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))
# Out:
# [(-20, 160)]

# %%
sns.set_style("dark" , {"axes.facecolor": "black"})
f, axes = plt.subplots(2,2, figsize=(15,15))
#plot[0,0]
k1 = sns.kdeplot(movies.BudgetMilloions  ,movies.AudienceRating ,shade=True ,shade_lowest=True , cmap='inferno',ax=axes[0,0])
k1b = sns.kdeplot(movies.BudgetMilloions  ,movies.AudienceRating , cmap='cool',ax=axes[0,0])
#plot[0,1]
k2 = sns.kdeplot(movies.BudgetMilloions , movies.CriticRating ,shade=True ,shade_lowest=True , cmap='inferno' , ax=axes[0,1])
k2b = sns.kdeplot(movies.BudgetMilloions , movies.CriticRating, cmap='cool' , ax=axes[0,1])
#plot[1,0]
z = sns.violinplot(data=movies[movies.Genre=='Drama'] ,x='Year' , y='CriticRating' , ax=axes[1,0])
#plot[1,1]
k4 = sns.kdeplot(movies.CriticRating  ,movies.AudienceRating ,shade=True ,shade_lowest=False , cmap='Blues_r', ax=axes[1,1])
k4b = sns.kdeplot(movies.CriticRating  ,movies.AudienceRating , cmap='gist_gray_r',ax=axes[1,1])
k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))
# Out:
# [(-20, 160)]

# %%
sns.set_style("dark" , {"axes.facecolor": "black"})
f, axes = plt.subplots(2,2, figsize=(15,15))
#plot[0,0]
k1 = sns.kdeplot(movies.BudgetMilloions  ,movies.AudienceRating ,shade=True ,shade_lowest=True , cmap='inferno',ax=axes[0,0])
k1b = sns.kdeplot(movies.BudgetMilloions  ,movies.AudienceRating , cmap='cool',ax=axes[0,0])
#plot[0,1]
k2 = sns.kdeplot(movies.BudgetMilloions , movies.CriticRating ,shade=True ,shade_lowest=True , cmap='inferno' , ax=axes[0,1])
k2b = sns.kdeplot(movies.BudgetMilloions , movies.CriticRating, cmap='cool' , ax=axes[0,1])
#plot[1,0]
z = sns.violinplot(data=movies ,x='Year' , y='BudgetMilloions' ,palette='YlOrRd', ax=axes[1,0])
#plot[1,1]
k4 = sns.kdeplot(movies.CriticRating  ,movies.AudienceRating ,shade=True ,shade_lowest=False , cmap='Blues_r', ax=axes[1,1])
k4b = sns.kdeplot(movies.CriticRating  ,movies.AudienceRating , cmap='gist_gray_r',ax=axes[1,1])
k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))
# Out:
# [(-20, 160)]

# %%
#Thematic edits

# %%
list1 = list()
mylabels = list()
for gen in movies.Genre.cat.categories:
    list1.append(movies[movies.Genre == gen].BudgetMilloions)
    mylabels.append(gen)
sns.set_style("whitegrid") 
fig, ax = plt.subplots()
fig.set_size_inches(11.7,8.27) #size of A4 paper
h = plt.hist(list1, bins=15, stacked=True, label=mylabels)
plt.title("Movie Budget Distribution" , fontsize=35 ,color="DarkBlue" ,fontname="Console")
plt.ylabel("Number of Movies" ,fontsize=25 , color="Red")
plt.xlabel("Budget" ,fontsize=25 , color="Green")
plt.yticks(fontsize=20)
plt.xticks(fontsize=20)
plt.legend(frameon=True , fancybox=True ,shadow=True , framealpha=1 , prop={'size':20})
plt.show()
